# %%
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
import os
import glob
import shutil
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

batch_size = 128
IMG_SHAPE = 64
base_dir = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)"

# %%
classes = ['NoSunglasses','YesSunglasses']

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '*.pgm')
  print("{}: {} Images".format(cl, len(images)))
  train, val = images[:round(len(images)*0.8)], images[round(len(images)*0.8):]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# NoSunglasses: 313 Images
# YesSunglasses: 311 Images

# %%
BASE_DIR = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/train"
image_dir = os.path.join(BASE_DIR, "YesSunglasses")
count = 0
path = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/train/YesSunglasses/"
for root, dirs, files in os.walk(image_dir):
  for file in files:
    if file.endswith("pgm"):
      path = os.path.join(root, file)
      img = cv2.imread(path,0)
      cv2.imwrite(path + str(count) + ".png",img )
      count = count + 1

BASE_DIR = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/val"
image_dir = os.path.join(BASE_DIR, "NoSunglasses")
count = 300
path = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/val/NoSunglasses/"
for root, dirs, files in os.walk(image_dir):
  for file in files:
    if file.endswith("pgm"):
      path = os.path.join(root, file)
      img = cv2.imread(path,0)
      cv2.imwrite(path + str(count) + ".png",img )
      count = count + 1

BASE_DIR = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/val"
image_dir = os.path.join(BASE_DIR, "YesSunglasses")
count = 300
path = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/val/YesSunglasses/"
for root, dirs, files in os.walk(image_dir):
  for file in files:
    if file.endswith("pgm"):
      path = os.path.join(root, file)
      img = cv2.imread(path,0)
      cv2.imwrite(path + str(count) + ".png",img )
      count = count + 1

# %%
BASE_DIR = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/train"
image_dir = os.path.join(BASE_DIR, "NoSunglasses")
count = 0
path = "/content/drive/My Drive/Intermediate_Assignment_Dataset (1)/train/NoSunglasses/"
for root, dirs, files in os.walk(image_dir):
  for file in files:
    if file.endswith("pgm"):
      path = os.path.join(root, file)
      img = cv2.imread(path,0)
      cv2.imwrite(path + str(count) + ".png",img )
      count = count + 1

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %%
image_gen_train = ImageDataGenerator(
      rescale=1./255,
      rotation_range=45,
      width_shift_range=0.2,
      height_shift_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

train_data_gen = image_gen_train.flow_from_directory(batch_size=batch_size,
                                                     directory=train_dir,
                                                     shuffle=True,
                                                     target_size=(IMG_SHAPE,IMG_SHAPE),
                                                     class_mode='sparse')
# Out:
# Found 499 images belonging to 2 classes.

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 125 images belonging to 2 classes.

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(64,64,3)),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),),

        tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),),

        tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),),

        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512,activation='relu'),
        tf.keras.layers.Dense(2)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_61 (Conv2D)           (None, 62, 62, 16)        160
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 31, 31, 16)        0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 29, 29, 32)        4640
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,204,482
# Trainable params: 1,204,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=80
history = model.fit_generator(
    train_data_gen,
    epochs=epochs,
    validation_data=val_data_gen,
)
model.save_weights("weights.h5")
# Out:
# Epoch 1/80
# 4/4 [==============================] - 3s 680ms/step - loss: 0.7063 - accuracy: 0.5130 - val_loss: 0.7146 - val_accuracy: 0.4960
# Epoch 2/80
# 4/4 [==============================] - 3s 665ms/step - loss: 0.6966 - accuracy: 0.5070 - val_loss: 0.6792 - val_accuracy: 0.5200
# Epoch 3/80
# 4/4 [==============================] - 3s 677ms/step - loss: 0.6916 - accuracy: 0.5291 - val_loss: 0.6731 - val_accuracy: 0.7920
# Epoch 4/80
# 4/4 [==============================] - 3s 688ms/step - loss: 0.6796 - accuracy: 0.5912 - val_loss: 0.6527 - val_accuracy: 0.4960
# Epoch 5/80
# 4/4 [==============================] - 3s 655ms/step - loss: 0.6653 - accuracy: 0.5471 - val_loss: 0.5918 - val_accuracy: 0.7680
# Epoch 6/80
# 4/4 [==============================] - 3s 656ms/step - loss: 0.6327 - accuracy: 0.7074 - val_loss: 0.5021 - val_accuracy: 0.7680
# Epoch 7/80
# 4/4 [==============================] - 3s 651ms/step - loss: 0.5920 - accuracy: 0.6814 - val_loss: 0.3987 - val_accuracy: 0.8560
# Epoch 8/80
# 4/4 [==============================] - 3s 686ms/step - loss: 0.5576 - accuracy: 0.7234 - val_loss: 0.3787 - val_accuracy: 0.8160
# Epoch 9/80
# 4/4 [==============================] - 3s 652ms/step - loss: 0.5709 - accuracy: 0.6994 - val_loss: 0.3711 - val_accuracy: 0.7760
# Epoch 10/80
# 4/4 [==============================] - 3s 673ms/step - loss: 0.5448 - accuracy: 0.7114 - val_loss: 0.3021 - val_accuracy: 0.8960
# Epoch 11/80
# 4/4 [==============================] - 3s 670ms/step - loss: 0.5265 - accuracy: 0.7375 - val_loss: 0.4299 - val_accuracy: 0.7360
# Epoch 12/80
# 4/4 [==============================] - 3s 672ms/step - loss: 0.5291 - accuracy: 0.7415 - val_loss: 0.2906 - val_accuracy: 0.9200
# Epoch 13/80
# 4/4 [==============================] - 3s 685ms/step - loss: 0.4786 - accuracy: 0.7816 - val_loss: 0.3452 - val_accuracy: 0.7760
# Epoch 14/80
# 4/4 [==============================] - 3s 653ms/step - loss: 0.4899 - accuracy: 0.7735 - val_loss: 0.2148 - val_accuracy: 0.9520
# Epoch 15/80
# 4/4 [==============================] - 3s 704ms/step - loss: 0.4789 - accuracy: 0.7796 - val_loss: 0.3051 - val_accuracy: 0.8000
# Epoch 16/80
# 4/4 [==============================] - 3s 660ms/step - loss: 0.4522 - accuracy: 0.7856 - val_loss: 0.2752 - val_accuracy: 0.8080
# Epoch 17/80
# 4/4 [==============================] - 3s 665ms/step - loss: 0.4200 - accuracy: 0.7896 - val_loss: 0.2047 - val_accuracy: 0.9280
# Epoch 18/80
# 4/4 [==============================] - 3s 666ms/step - loss: 0.3927 - accuracy: 0.8337 - val_loss: 0.3240 - val_accuracy: 0.7760
# Epoch 19/80
# 4/4 [==============================] - 3s 668ms/step - loss: 0.3621 - accuracy: 0.8377 - val_loss: 0.3759 - val_accuracy: 0.7360
# Epoch 20/80
# 4/4 [==============================] - 3s 677ms/step - loss: 0.3499 - accuracy: 0.8597 - val_loss: 0.2217 - val_accuracy: 0.8880
# Epoch 21/80
# 4/4 [==============================] - 3s 659ms/step - loss: 0.3449 - accuracy: 0.8537 - val_loss: 0.3038 - val_accuracy: 0.7760
# Epoch 22/80
# 4/4 [==============================] - 3s 684ms/step - loss: 0.3210 - accuracy: 0.8637 - val_loss: 0.2763 - val_accuracy: 0.7920
# Epoch 23/80
# 4/4 [==============================] - 3s 685ms/step - loss: 0.3521 - accuracy: 0.8557 - val_loss: 0.0584 - val_accuracy: 1.0000
# Epoch 24/80
# 4/4 [==============================] - 3s 652ms/step - loss: 0.3450 - accuracy: 0.8357 - val_loss: 0.0820 - val_accuracy: 0.9920
# Epoch 25/80
# 4/4 [==============================] - 3s 698ms/step - loss: 0.3033 - accuracy: 0.8758 - val_loss: 0.3209 - val_accuracy: 0.8000
# Epoch 26/80
# 4/4 [==============================] - 3s 685ms/step - loss: 0.3014 - accuracy: 0.8818 - val_loss: 0.1396 - val_accuracy: 0.9680
# Epoch 27/80
# 4/4 [==============================] - 3s 638ms/step - loss: 0.2801 - accuracy: 0.8818 - val_loss: 0.1855 - val_accuracy: 0.9200
# Epoch 28/80
# 4/4 [==============================] - 3s 662ms/step - loss: 0.2942 - accuracy: 0.8737 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 29/80
# 4/4 [==============================] - 3s 642ms/step - loss: 0.3072 - accuracy: 0.8517 - val_loss: 0.9404 - val_accuracy: 0.6880
# Epoch 30/80
# 4/4 [==============================] - 3s 713ms/step - loss: 0.3101 - accuracy: 0.8838 - val_loss: 0.0556 - val_accuracy: 0.9920
# Epoch 31/80
# 4/4 [==============================] - 3s 677ms/step - loss: 0.2742 - accuracy: 0.8878 - val_loss: 0.6011 - val_accuracy: 0.7200
# Epoch 32/80
# 4/4 [==============================] - 3s 661ms/step - loss: 0.2805 - accuracy: 0.8958 - val_loss: 0.0587 - val_accuracy: 0.9920
# Epoch 33/80
# 4/4 [==============================] - 3s 641ms/step - loss: 0.2356 - accuracy: 0.9038 - val_loss: 0.7737 - val_accuracy: 0.7120
# Epoch 34/80
# 4/4 [==============================] - 3s 650ms/step - loss: 0.2312 - accuracy: 0.9118 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 35/80
# 4/4 [==============================] - 3s 651ms/step - loss: 0.2325 - accuracy: 0.9038 - val_loss: 0.6982 - val_accuracy: 0.7200
# Epoch 36/80
# 4/4 [==============================] - 3s 647ms/step - loss: 0.2554 - accuracy: 0.8838 - val_loss: 0.0454 - val_accuracy: 0.9920
# Epoch 37/80
# 4/4 [==============================] - 3s 661ms/step - loss: 0.2228 - accuracy: 0.9098 - val_loss: 0.4179 - val_accuracy: 0.7920
# Epoch 38/80
# 4/4 [==============================] - 3s 648ms/step - loss: 0.2071 - accuracy: 0.9279 - val_loss: 0.0795 - val_accuracy: 0.9840
# Epoch 39/80
# 4/4 [==============================] - 3s 630ms/step - loss: 0.2023 - accuracy: 0.9158 - val_loss: 0.5224 - val_accuracy: 0.7440
# Epoch 40/80
# 4/4 [==============================] - 3s 661ms/step - loss: 0.2104 - accuracy: 0.8998 - val_loss: 0.0503 - val_accuracy: 0.9920
# Epoch 41/80
# 4/4 [==============================] - 3s 641ms/step - loss: 0.1940 - accuracy: 0.9178 - val_loss: 0.6360 - val_accuracy: 0.7120
# Epoch 42/80
# 4/4 [==============================] - 3s 658ms/step - loss: 0.1843 - accuracy: 0.9178 - val_loss: 0.0945 - val_accuracy: 0.9680
# Epoch 43/80
# 4/4 [==============================] - 3s 684ms/step - loss: 0.1539 - accuracy: 0.9419 - val_loss: 0.3962 - val_accuracy: 0.8000
# Epoch 44/80
# 4/4 [==============================] - 3s 662ms/step - loss: 0.1818 - accuracy: 0.9238 - val_loss: 0.1544 - val_accuracy: 0.9280
# Epoch 45/80
# 4/4 [==============================] - 3s 720ms/step - loss: 0.1570 - accuracy: 0.9439 - val_loss: 0.3390 - val_accuracy: 0.8160
# Epoch 46/80
# 4/4 [==============================] - 3s 795ms/step - loss: 0.1797 - accuracy: 0.9399 - val_loss: 0.2214 - val_accuracy: 0.8880
# Epoch 47/80
# 4/4 [==============================] - 3s 741ms/step - loss: 0.1376 - accuracy: 0.9439 - val_loss: 0.1632 - val_accuracy: 0.9280
# Epoch 48/80
# 4/4 [==============================] - 3s 628ms/step - loss: 0.1300 - accuracy: 0.9559 - val_loss: 0.1882 - val_accuracy: 0.8960
# Epoch 49/80
# 4/4 [==============================] - 2s 625ms/step - loss: 0.1141 - accuracy: 0.9659 - val_loss: 0.5077 - val_accuracy: 0.7840
# Epoch 50/80
# 4/4 [==============================] - 3s 689ms/step - loss: 0.1483 - accuracy: 0.9519 - val_loss: 0.1322 - val_accuracy: 0.9280
# Epoch 51/80
# 4/4 [==============================] - 3s 648ms/step - loss: 0.1321 - accuracy: 0.9479 - val_loss: 0.5060 - val_accuracy: 0.7840
# Epoch 52/80
# 4/4 [==============================] - 3s 678ms/step - loss: 0.1681 - accuracy: 0.9319 - val_loss: 0.1324 - val_accuracy: 0.9360
# Epoch 53/80
# 4/4 [==============================] - 3s 649ms/step - loss: 0.1406 - accuracy: 0.9539 - val_loss: 0.2822 - val_accuracy: 0.8640
# Epoch 54/80
# 4/4 [==============================] - 3s 656ms/step - loss: 0.1263 - accuracy: 0.9559 - val_loss: 0.1646 - val_accuracy: 0.9280
# Epoch 55/80
# 4/4 [==============================] - 3s 668ms/step - loss: 0.1259 - accuracy: 0.9559 - val_loss: 0.2369 - val_accuracy: 0.8800
# Epoch 56/80
# 4/4 [==============================] - 3s 645ms/step - loss: 0.1390 - accuracy: 0.9359 - val_loss: 0.4173 - val_accuracy: 0.8240
# Epoch 57/80
# 4/4 [==============================] - 3s 668ms/step - loss: 0.1138 - accuracy: 0.9539 - val_loss: 0.2996 - val_accuracy: 0.8640
# Epoch 58/80
# 4/4 [==============================] - 3s 681ms/step - loss: 0.1614 - accuracy: 0.9379 - val_loss: 0.1097 - val_accuracy: 0.9520
# Epoch 59/80
# 4/4 [==============================] - 3s 641ms/step - loss: 0.1085 - accuracy: 0.9559 - val_loss: 0.2082 - val_accuracy: 0.9040
# Epoch 60/80
# 4/4 [==============================] - 3s 648ms/step - loss: 0.1125 - accuracy: 0.9519 - val_loss: 0.1054 - val_accuracy: 0.9520
# Epoch 61/80
# 4/4 [==============================] - 3s 693ms/step - loss: 0.1024 - accuracy: 0.9619 - val_loss: 0.3372 - val_accuracy: 0.8640
# Epoch 62/80
# 4/4 [==============================] - 3s 681ms/step - loss: 0.1006 - accuracy: 0.9559 - val_loss: 0.3343 - val_accuracy: 0.8640
# Epoch 63/80
# 4/4 [==============================] - 3s 664ms/step - loss: 0.1251 - accuracy: 0.9499 - val_loss: 0.1025 - val_accuracy: 0.9440
# Epoch 64/80
# 4/4 [==============================] - 3s 678ms/step - loss: 0.1154 - accuracy: 0.9559 - val_loss: 0.4824 - val_accuracy: 0.8160
# Epoch 65/80
# 4/4 [==============================] - 3s 648ms/step - loss: 0.1169 - accuracy: 0.9599 - val_loss: 0.0834 - val_accuracy: 0.9680
# Epoch 66/80
# 4/4 [==============================] - 3s 651ms/step - loss: 0.0998 - accuracy: 0.9599 - val_loss: 0.6463 - val_accuracy: 0.7840
# Epoch 67/80
# 4/4 [==============================] - 3s 657ms/step - loss: 0.1113 - accuracy: 0.9599 - val_loss: 0.2134 - val_accuracy: 0.9200
# Epoch 68/80
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0919 - accuracy: 0.9659 - val_loss: 0.3885 - val_accuracy: 0.8320
# Epoch 69/80
# 4/4 [==============================] - 3s 766ms/step - loss: 0.0875 - accuracy: 0.9659 - val_loss: 0.2816 - val_accuracy: 0.8960
# Epoch 70/80
# 4/4 [==============================] - 3s 672ms/step - loss: 0.1232 - accuracy: 0.9539 - val_loss: 0.2222 - val_accuracy: 0.9120
# Epoch 71/80
# 4/4 [==============================] - 3s 651ms/step - loss: 0.1145 - accuracy: 0.9559 - val_loss: 0.3160 - val_accuracy: 0.8800
# Epoch 72/80
# 4/4 [==============================] - 3s 682ms/step - loss: 0.1104 - accuracy: 0.9519 - val_loss: 0.2227 - val_accuracy: 0.9120
# Epoch 73/80
# 4/4 [==============================] - 3s 666ms/step - loss: 0.0974 - accuracy: 0.9739 - val_loss: 0.1799 - val_accuracy: 0.9200
# Epoch 74/80
# 4/4 [==============================] - 3s 680ms/step - loss: 0.1155 - accuracy: 0.9559 - val_loss: 0.3121 - val_accuracy: 0.8800
# Epoch 75/80
# 4/4 [==============================] - 3s 638ms/step - loss: 0.1165 - accuracy: 0.9559 - val_loss: 0.2312 - val_accuracy: 0.9120
# Epoch 76/80
# 4/4 [==============================] - 3s 640ms/step - loss: 0.0785 - accuracy: 0.9820 - val_loss: 0.2266 - val_accuracy: 0.9200
# Epoch 77/80
# 4/4 [==============================] - 3s 684ms/step - loss: 0.0810 - accuracy: 0.9739 - val_loss: 0.3057 - val_accuracy: 0.8800
# Epoch 78/80
# 4/4 [==============================] - 3s 664ms/step - loss: 0.0666 - accuracy: 0.9800 - val_loss: 0.2340 - val_accuracy: 0.9200
# Epoch 79/80
# 4/4 [==============================] - 3s 700ms/step - loss: 0.0973 - accuracy: 0.9659 - val_loss: 0.3482 - val_accuracy: 0.8720
# Epoch 80/80
# 4/4 [==============================] - 3s 664ms/step - loss: 0.0669 - accuracy: 0.9739 - val_loss: 0.3077 - val_accuracy: 0.8880

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Out:
# (125, 2)
# (125,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-4a171d7675eb> in <module>()
#      15
#      16 # accuracy: (tp + tn) / (p + n)
# ---> 17 accuracy = accuracy_score(testy, yhat_classes)
#      18 print('Accuracy: %f' % accuracy)
#      19 # precision tp / (tp + fp)
#
# NameError: name 'testy' is not defined
